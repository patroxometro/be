# %%
import pandas as pd

# %%
alertas = pd.read_excel('/Users/plop/Desktop/Prueba_AlertasHMS_AD23.xlsx')
alertas.head()
# Out:
#   identificador            Región     Campus Alto riesgo de suicidio  \
# 0     A01708084        Centro/Sur  Querétaro                      Sí
# 1     A01769383  Ciudad de México     Toluca                      Sí
# 2     A01769517  Ciudad de México     Toluca                      Sí
# 3     A01737978        Centro/Sur     Puebla                      Sí
# 4     A01198945         Monterrey  Monterrey                      Sí
#
#   Abuso sexual y alto riesgo de suicidio Conducta suicida  \
# 0                                     Sí               Sí
# 1                                     Sí               Sí
# 2                                     No               Sí
# 3                                     No               Sí
# 4                                     No               Sí
#
#   Problemas emocionales Desórdenes Alimenticios Consumo de alcohol Soledad  \
# 0                    Sí                      No                 No      No
# ...
